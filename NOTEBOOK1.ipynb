# %% [markdown]
# <a href="https://colab.research.google.com/github/luismenco2315-cpu/notebook_luis23/blob/main/NOTEBOOK1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #CONRENIDIOS
#
# 1. INTRODUCCION
# 2. OBJETIVOS
# 3. METODOLOGIA
# 4. ANALISIS
# 5. ECCUACIONES

# %% [markdown]
# # INTRODUCCION
#
# SVCVHVCJVJVCJCSDBKCHBSDHBCSDFHIDSBFDSBFJBNDVJASDBJHBASHBHSBFKSBFKASBFKASBKBSKBKBSKHBHFSSAHFHKBKHFBKHFBFHKBKHFBSF

# %% [markdown]
# # OBJETIVOS
#
# BASBSFBASFAHFBAHFBFHFBFHFBDFJNSDFNDFSHSFDBDFJDFBHSDFDFBDFFBDDFBSDFHSDFBDSBDHDSNDHDH

# %% [markdown]
# ## OBJETIVO GENERAL
#
# BDHBIBFIHFBIHBFIHBFIHBIHFHIFBHIBFBFIHBFHIFBJIBDJBDSFJDASJSAJSABJHSADBIJHSDJHBISBFHJIBFHIBFIHABSIFBNIFDHBFUOFHOUHFUASJFSJABFIFYFGHFIOASHBDFUHGUYSFUSAHUSHUSUSAHSAJHOSOHSAF

# %% [markdown]
# ## OBJETIVOS ESPECIFICOS
#
# + PRIMER OBJETIVO
# + SEGUNDO OBJETIVO
# + TERCER OBJETIVOS

# %% [markdown]
# # ECUACIONES
# 1. ECUACION DE LA ENERGIA: $$E=M*C^2$$
#
# Todas la ecuaciones en formnatos latres markdownse encuentra en el siguiente link
#
# [Apuntes de latex](https://metodos.fam.cie.uva.es/~latex/apuntes/apuntes3.pdf )
